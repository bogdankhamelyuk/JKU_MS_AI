# %%
# !pip install ndjson
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ndjson
#   Downloading ndjson-0.3.1-py2.py3-none-any.whl (5.3 kB)
# Installing collected packages: ndjson
# Successfully installed ndjson-0.3.1

# %%
import cv2
import requests
import ndjson
import json
import os

# %%
# !pip install labelbox
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting labelbox
#   Downloading labelbox-3.34.0-py3-none-any.whl (185 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.5/185.5 KB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from labelbox) (4.64.1)
# Requirement already satisfied: google-api-core>=1.22.1 in /usr/local/lib/python3.8/dist-packages (from labelbox) (2.11.0)
# Requirement already satisfied: requests>=2.22.0 in /usr/local/lib/python3.8/dist-packages (from labelbox) (2.25.1)
# Requirement already satisfied: ndjson in /usr/local/lib/python3.8/dist-packages (from labelbox) (0.3.1)
# Collecting backoff==1.10.0
#   Downloading backoff-1.10.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: pydantic<2.0,>=1.8 in /usr/local/lib/python3.8/dist-packages (from labelbox) (1.10.2)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.8/dist-packages (from google-api-core>=1.22.1->labelbox) (3.19.6)
# Requirement already satisfied: google-auth<3.0dev,>=2.14.1 in /usr/local/lib/python3.8/dist-packages (from google-api-core>=1.22.1->labelbox) (2.15.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.8/dist-packages (from google-api-core>=1.22.1->labelbox) (1.57.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.8/dist-packages (from pydantic<2.0,>=1.8->labelbox) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.22.0->labelbox) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.22.0->labelbox) (1.24.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.22.0->labelbox) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.22.0->labelbox) (2.10)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core>=1.22.1->labelbox) (1.15.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core>=1.22.1->labelbox) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core>=1.22.1->labelbox) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0dev,>=2.14.1->google-api-core>=1.22.1->labelbox) (4.9)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.14.1->google-api-core>=1.22.1->labelbox) (0.4.8)
# Installing collected packages: backoff, labelbox
# Successfully installed backoff-1.10.0 labelbox-3.34.0

# %%
from labelbox import Client
API_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..byH8m7_7qZZCxO3SHY14JIS_Xer0JPy5i-WH16DJ5jM"
client = Client(api_key=API_KEY)
project = client.get_project('clbtwzgas9u4g070i4kr26byi')

# %%
export_url = project.export_labels()

# %%
print(export_url)
# Out:
# https://storage.googleapis.com/labelbox-exports/clbtmezfb9ynn0810gndi69vm/clbtwzgas9u4g070i4kr26byi/export-2023-01-08T15%3A39%3A57.934Z.json?GoogleAccessId=sa-lb-api-0da28c-7505d6%40labelbox-193903.iam.gserviceaccount.com&Expires=1674402041&Signature=csY5L9MpTEGZ0CInlPEARwx5Mu8tG7iVEVINRU094vOjcCLf7y3iRusUE1bzitPgm1h94m0IcoLSlob72KFPIpTxUNnJ7GZgyuVGPAcV%2FNIwa51BTU2ea3kOINACHAIMEeIjxesfx43bqZiIB1fCdkUfWxfP9lVMWCCbmmNfJLKwVsNwd%2BwjU8KI5PV2CpzlqfAvh72rc4RkOllU3Q%2FyHMBTiqpvfAdh1vFsZq%2FA4VBCnAXVrjMKNIy3gd8rY145nLgA1pdz8t5Exv15r34gk8oGTpRIFRxQ2kOhlGwVwgez0YCcVlAWRl86ybOIPvFOO3HKQJluL8mPejWppnqx%2BQ%3D%3D&response-content-disposition=attachment

# %%
exports = requests.get(export_url).json()

# %%
exports[-1]
# Out:
# {'ID': 'clbwu307b0bnt08ylb0u0ermn',
#  'DataRow ID': 'clbty4ve53wg6077q7jsqbz8b',
#  'Labeled Data': 'https://storage.labelbox.com/clbtmezfb9ynn0810gndi69vm%2F34b6ff48-b004-77c2-deb6-b4859649bd35-video_021.mp4?Expires=1674401998004&KeyName=labelbox-assets-key-3&Signature=QGslW89V458Ynk3H_xdY4xZRGkw',
#  'Label': {'objects': [],
#   'classifications': [],
#   'relationships': [],
#   'frames': 'https://api.labelbox.com/v1/frames/clbwu307b0bnt08ylb0u0ermn'},
#  'Created By': 'k01563404@students.jku.at',
#  'Project Name': 'CV_1st_sem',
#  'Created At': '2022-12-21T01:42:45.000Z',
#  'Updated At': '2022-12-21T10:41:32.000Z',
#  'Seconds to Label': 1434.091,
#  'Seconds to Review': 215.081,
#  'Seconds to Create': 1219.01,
#  'External ID': 'video_021.mp4',
#  'Global Key': None,
#  'Agreement': -1,
#  'Is Benchmark': 0,
#  'Benchmark Agreement': -1,
#  'Benchmark ID': None,
#  'Dataset Name': 'thermal_drone',
#  'Reviews': [],
#  'View Label': 'https://editor.labelbox.com?project=clbtwzgas9u4g070i4kr26byi&label=clbwu307b0bnt08ylb0u0ermn',
#  'Has Open Issues': 0,
#  'Skipped': False,
#  'DataRow Workflow Info': {'taskName': 'Done',
#   'Workflow History': [{'actorId': 'clbuqqtt8078a07yj73upgysr',
#     'action': 'APPROVE',
#     'createdAt': '2022-12-21T10:42:31.097Z',
#     'previousTaskId': '0961cd12-5767-4d33-a16d-08ccac99a26d',
#     'previousTaskName': 'Initial review task'},
#    {'actorId': 'clbtmezht9yno08101oq52st1',
#     'action': 'MOVE',
#     'createdAt': '2022-12-21T01:42:44.652Z',
#     'previousTaskId': 'b8477538-365d-0793-b9de-6335bb6c6a0e',
#     'previousTaskName': 'Initial labeling task',
#     'nextTaskId': '0961cd12-5767-4d33-a16d-08ccac99a26d',
#     'nextTaskName': 'Initial review task'},
#    {'actorId': 'clbtmezht9yno08101oq52st1',
#     'action': 'MOVE',
#     'createdAt': '2022-12-21T01:42:44.632Z',
#     'nextTaskId': 'b8477538-365d-0793-b9de-6335bb6c6a0e',
#     'nextTaskName': 'Initial labeling task'}]}}

# %%
annotations_url = exports[0]["Label"]["frames"]
print(annotations_url)
# Out:
# https://api.labelbox.com/v1/frames/clbty7zctbk8q0718gdxg6mtg

# %%
headers = {"Authorization": f"Bearer {API_KEY}"}
annotations = ndjson.loads(requests.get(annotations_url, headers=headers).text)

# %%
annotations[-1]
# Out:
# {'frameNumber': 1622,
#  'classifications': [],
#  'objects': [{'featureId': 'clbtzclng0002356j9e85dyy7',
#    'schemaId': 'clbtzax16ba0d081m5f8q2250',
#    'title': 'Target',
#    'value': 'target',
#    'color': '#1CE6FF',
#    'keyframe': True,
#    'point': {'x': 223.61, 'y': 67.424},
#    'classifications': []}],
#  'relationships': []}
